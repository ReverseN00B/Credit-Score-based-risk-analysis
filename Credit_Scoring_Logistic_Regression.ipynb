# %% [markdown]
# Data Importation

# %%
import pandas as pd
import seaborn as sns

# %%
# prompt: input excel file from drive into pandas dataframe

from google.colab import drive
drive.mount('/content/drive')

# Read the Excel file into a Pandas DataFrame
df = pd.read_excel('//content/drive/MyDrive/Colab Notebooks/a_Dataset_CreditScoring.xlsx')

# Print the DataFrame
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    TARGET    ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1   582         3           3             0         4          0.0
# 1       1   662        15           9             0         3          1.0
# 2       1   805         0           0             0         1          5.0
# 3       1  1175         8           5             0         6          1.0
# 4       1  1373         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  TLBalHCPct  \
# 0                5          117          27  ...          3.0      0.9179
# 1                3           14          14  ...          1.0      0.8000
# 2                1          354           7  ...          5.0      0.3552
# 3               10           16           4  ...          3.0      0.9127
# ...

# %%
# prompt: give me all the columns names in df

df.columns
# Out:
# Index(['TARGET', 'ID', 'DerogCnt', 'CollectCnt', 'BanruptcyInd', 'InqCnt06',
#        'InqTimeLast', 'InqFinanceCnt24', 'TLTimeFirst', 'TLTimeLast',
#        'TLCnt03', 'TLCnt12', 'TLCnt24', 'TLCnt', 'TLSum', 'TLMaxSum',
#        'TLSatCnt', 'TLDel60Cnt', 'TLBadCnt24', 'TL75UtilCnt', 'TL50UtilCnt',
#        'TLBalHCPct', 'TLSatPct', 'TLDel3060Cnt24', 'TLDel90Cnt24',
#        'TLDel60CntAll', 'TLOpenPct', 'TLBadDerogCnt', 'TLDel60Cnt24',
#        'TLOpen24Pct'],
#       dtype='object')

# %% [markdown]
# Data Preprocessing

# %%
# No need of customer ID in analysis
df.drop('ID',axis=1, inplace= True)

# %%
df.columns
# Out:
# Index(['TARGET', 'DerogCnt', 'CollectCnt', 'BanruptcyInd', 'InqCnt06',
#        'InqTimeLast', 'InqFinanceCnt24', 'TLTimeFirst', 'TLTimeLast',
#        'TLCnt03', 'TLCnt12', 'TLCnt24', 'TLCnt', 'TLSum', 'TLMaxSum',
#        'TLSatCnt', 'TLDel60Cnt', 'TLBadCnt24', 'TL75UtilCnt', 'TL50UtilCnt',
#        'TLBalHCPct', 'TLSatPct', 'TLDel3060Cnt24', 'TLDel90Cnt24',
#        'TLDel60CntAll', 'TLOpenPct', 'TLBadDerogCnt', 'TLDel60Cnt24',
#        'TLOpen24Pct'],
#       dtype='object')

# %% [markdown]
# Few of these features we are intreseted in
#
# 1.   Target 🚀: The target variable that indicates loan turned out Good 0 or bad 1. this is our dependent variable.
# 2.   DerigCnt : Count of Public derogatories that is number of late payments or defaults.
# 3.   BanruptcyInd : Bancruptcy Indicator is likelyhood of filing for Bancruptcy.
# 4.   InqCnt06 : Number of Inquiries in past 6 months.
# 5.   InqFinanceCnt24 : Number of Financial Inquiries in last 24 months.

# %%
df.describe()
# Out:
#             TARGET     DerogCnt   CollectCnt  BanruptcyInd     InqCnt06  \
# count  3000.000000  3000.000000  3000.000000   3000.000000  3000.000000
# mean      0.166667     1.430000     0.857000      0.153333     3.108333
# std       0.372740     2.731469     2.161352      0.360369     3.479171
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000     0.000000      0.000000     1.000000
# 50%       0.000000     0.000000     0.000000      0.000000     2.000000
# 75%       0.000000     2.000000     1.000000      0.000000     4.000000
# max       1.000000    51.000000    50.000000      1.000000    40.000000
#
#        InqTimeLast  InqFinanceCnt24  TLTimeFirst   TLTimeLast      TLCnt03  \
# count  2812.000000      3000.000000  3000.000000  3000.000000  3000.000000
# mean      3.108108         3.555000   170.113667    11.873667     0.275000
# std       4.637831         4.477536    92.813700    16.321412     0.582084
# ...

# %%
#  total missing values in df

df.isna().sum()
# Out:
# TARGET               0
# DerogCnt             0
# CollectCnt           0
# BanruptcyInd         0
# InqCnt06             0
# InqTimeLast        188
# InqFinanceCnt24      0
# TLTimeFirst          0
# TLTimeLast           0
# TLCnt03              0
# TLCnt12              0
# TLCnt24              0
# TLCnt                3
# TLSum               40
# TLMaxSum            40
# TLSatCnt             4
# TLDel60Cnt           0
# TLBadCnt24           0
# TL75UtilCnt         99
# TL50UtilCnt         99
# TLBalHCPct          41
# TLSatPct             4
# TLDel3060Cnt24       0
# TLDel90Cnt24         0
# TLDel60CntAll        0
# TLOpenPct            3
# TLBadDerogCnt        0
# TLDel60Cnt24         0
# TLOpen24Pct          3
# dtype: int64

# %%
#fill missing values with mean
df = df.fillna(df.mean())
df.isna().sum()
# Out:
# TARGET             0
# DerogCnt           0
# CollectCnt         0
# BanruptcyInd       0
# InqCnt06           0
# InqTimeLast        0
# InqFinanceCnt24    0
# TLTimeFirst        0
# TLTimeLast         0
# TLCnt03            0
# TLCnt12            0
# TLCnt24            0
# TLCnt              0
# TLSum              0
# TLMaxSum           0
# TLSatCnt           0
# TLDel60Cnt         0
# TLBadCnt24         0
# TL75UtilCnt        0
# TL50UtilCnt        0
# TLBalHCPct         0
# TLSatPct           0
# TLDel3060Cnt24     0
# TLDel90Cnt24       0
# TLDel60CntAll      0
# TLOpenPct          0
# TLBadDerogCnt      0
# TLDel60Cnt24       0
# TLOpen24Pct        0
# dtype: int64

# %%
# count of good loans (0) and bad loans (1)
df['TARGET'].value_counts()
# Out:
# TARGET
# 0    2500
# 1     500
# Name: count, dtype: int64

# %%
# data summary across 0 & 1
df.groupby('TARGET').mean()
# Out:
#         DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# TARGET
# 0         1.3224      0.7664        0.1492    2.9424     3.174638
# 1         1.9680      1.3100        0.1740    3.9380     2.775459
#
#         InqFinanceCnt24  TLTimeFirst  TLTimeLast  TLCnt03  TLCnt12  ...  \
# TARGET                                                              ...
# 0                3.2896      173.002      11.650   0.2844    1.832  ...
# 1                4.8820      155.672      12.992   0.2280    1.768  ...
#
#         TL50UtilCnt  TLBalHCPct  TLSatPct  TLDel3060Cnt24  TLDel90Cnt24  \
# TARGET
# 0          3.986711    0.628177  0.544963          0.6044        0.6624
# 1          4.533870    0.748185  0.385173          1.3340        1.5760
#
#         TLDel60CntAll  TLOpenPct  TLBadDerogCnt  TLDel60Cnt24  TLOpen24Pct
# TARGET
# 0              2.2236   0.502376          1.180        0.8648     0.556867
# 1              4.0140   0.465127          2.554        2.0860     0.600978
#
# ...

# %% [markdown]
# Split Train & test

# %%
# create Train Test Split
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
# X = df.drop('TARGET', axis=1)
# y = df.iloc[:, 0].values
y = df.iloc[:, 0].values
X = df.iloc[:, 1:29].values

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=0,
                                                    stratify = y)

# Applying Standardization Std Scaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Exporting Normalisation Coefficients for later use in prediction
import joblib
joblib.dump(sc, '/content/Normalisation_CreditScoring')
# Out:
# ['/content/Normalisation_CreditScoring']

# %% [markdown]
# Model Building

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)

# model.coef_
y_pred = model.predict(X_test)

# Exporting Logistic Regression Classifier for later use in prediction

# import joblib
joblib.dump(model, '/content/f1_Classifier_CreditScoring')
# Out:
# ['/content/f1_Classifier_CreditScoring']

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

print(confusion_matrix(y_test, y_pred))
# Out:
# [[487  13]
#  [ 87  13]]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8333333333333334

# %% [markdown]
# Writing output file

# %%
predictions = model.predict_proba(X_test)
predictions
# Out:
# array([[0.61644691, 0.38355309],
#        [0.9885656 , 0.0114344 ],
#        [0.87069686, 0.12930314],
#        ...,
#        [0.94450568, 0.05549432],
#        [0.46756903, 0.53243097],
#        [0.94014209, 0.05985791]])

# %%
# writing model output file

df_prediction_prob = pd.DataFrame(predictions, columns = ['prob_0', 'prob_1'])
df_prediction_target = pd.DataFrame(model.predict(X_test), columns = ['predicted_TARGET'])
df_test_dataset = pd.DataFrame(y_test,columns= ['Actual Outcome'])

dfx=pd.concat([df_test_dataset, df_prediction_prob, df_prediction_target], axis=1)

dfx.to_csv("/content/Model_Prediction.csv", sep=',', encoding='UTF-8')

dfx.head()
# Out:
#    Actual Outcome    prob_0    prob_1  predicted_TARGET
# 0               1  0.616447  0.383553                 0
# 1               0  0.988566  0.011434                 0
# 2               1  0.870697  0.129303                 0
# 3               0  0.953963  0.046037                 0
# 4               1  0.726633  0.273367                 0

# %%
# Exporting Logistic Regression Classifier for later use in prediction

# import joblib
joblib.dump(model, '/content/Classifier_CreditScoring')
# Out:
# ['/content/Classifier_CreditScoring']

# %%
# prompt: load the classifier and output the weights in a table format. one column with feature name and other with weights given by the classifier.
import joblib
# Load the saved classifier
loaded_model = joblib.load('/content/Classifier_CreditScoring')

# Get the feature names (assuming you have them available)
feature_names = df.columns[1:29]  # Adjust the range if needed

# Get the coefficients (weights) from the loaded model
coefficients = loaded_model.coef_[0]

# Create a DataFrame for display
weights_df = pd.DataFrame({
    'Feature': feature_names,
    'Weight': coefficients
})

# Display the table
print(weights_df)
# Out:
#             Feature    Weight
# 0          DerogCnt -0.030966
# 1        CollectCnt -0.055662
# 2      BanruptcyInd -0.109263
# 3          InqCnt06  0.118704
# 4       InqTimeLast  0.031174
# 5   InqFinanceCnt24  0.142841
# 6       TLTimeFirst -0.350437
# 7        TLTimeLast  0.139798
# 8           TLCnt03 -0.207357
# 9           TLCnt12 -0.075554
# 10          TLCnt24  0.088708
# 11            TLCnt  0.252083
# 12            TLSum -0.319029
# 13         TLMaxSum  0.316000
# 14         TLSatCnt -0.476400
# 15       TLDel60Cnt  0.436245
# 16       TLBadCnt24 -0.204912
# 17      TL75UtilCnt  0.417183
# 18      TL50UtilCnt  0.072869
# 19       TLBalHCPct  0.345013
# 20         TLSatPct -0.669392
# 21   TLDel3060Cnt24  0.420285
# 22     TLDel90Cnt24  0.116455
# 23    TLDel60CntAll -0.340922
# 24        TLOpenPct  0.077011
# 25    TLBadDerogCnt  0.215217
# 26     TLDel60Cnt24  0.079575
# 27      TLOpen24Pct  0.178171

# %% [markdown]
# # User input prediction with optimal threshold

# %%
# Calculate the mean values for all features
mean_values = df.mean()

# Create a new DataFrame with the custom values and mean values for other features
# new_data = pd.DataFrame({
#     'BanruptcyInd': [0],  # Example value
#     'TLBadDerogCnt': [2],
#     'InqFinanceCnt24': [5],
#     'DerogCnt': [1],
#     'TLDel3060Cnt24': [0],
#     'InqTimeLast': [12]
# })

new_data = pd.DataFrame({
    'DerogCnt': [2],
    'CollectCnt': [2],
    'BanruptcyInd': [1],
    'InqCnt06': [3.108333],
    'InqTimeLast': [3.108108],
    'InqFinanceCnt24': [3.555],
    'TLTimeFirst': [170.113667],
    'TLTimeLast': [11.873667],
    'TLCnt03': [0.275],
    'TLCnt12': [1.821333],
    'TLCnt24': [3.882333],
    'TLCnt': [7.879546],
    'TLSum': [20151.095608],
    'TLMaxSum': [31205.900676],
    'TLSatCnt': [13.511682],
    'TLDel60Cnt': [1.522],
    'TLBadCnt24': [0.567],
    'TL75UtilCnt': [3.121682],
    'TL50UtilCnt': [4.077904],
    'TLBalHCPct': [0.648178],
    'TLSatPct': [0.518331],
    'TLDel3060Cnt24': [0.726],
    'TLDel90Cnt24': [0.814667],
    'TLDel60CntAll': [2.522],
    'TLOpenPct': [0.496168],
    'TLBadDerogCnt': [1.409],
    'TLDel60Cnt24': [1.068333],
    'TLOpen24Pct': [0.564219]
})


# # Fill in the missing features with mean values
# for feature in df.columns:
#     if feature not in new_data.columns:
#         new_data[feature] = mean_values[feature]

# Load the saved normalization coefficients and logistic regression model
sc = joblib.load('/content/Normalisation_CreditScoring')
model = joblib.load('/content/f1_Classifier_CreditScoring')

# # Select the features used in the model
# features = ['BanruptcyInd', 'TLBadDerogCnt', 'InqFinanceCnt24','DerogCnt', 'TLDel3060Cnt24', 'InqTimeLast']
# input_features = new_data[features]

# new_data.head()

input_features = new_data.values
# Standardize the input features using the loaded scaler
input_features_scaled = sc.transform(input_features)

# Get the predicted probabilities
probabilities = model.predict_proba(input_features_scaled)


print(probabilities)
# Set the threshold to 84%
threshold = 0.74

# Make the prediction based on the threshold
prediction = (probabilities[:, 1] > threshold).astype(int)

# Print the prediction
print(prediction)
# Out:
# [[0.91175304 0.08824696]]
# [0]
